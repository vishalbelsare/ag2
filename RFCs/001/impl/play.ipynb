# %%
from  selector_parser import SelectorParser, SelectorTransformer

# %%
parser = SelectorParser()

# Valid JSON examples
selector_examples = [
    '{"key": "value"}',
    '{"key": 123}',
    '{key: "value"}',
    '{key: $var}',
    '{"key": True}',
    '{"key": False}',
    '{"key": None}',
    '{"key": [1, 2, 3]}',
    '{"key": {"nested": "value"}}',
    '{k:122, **rest}',
    '[1, 2, 3]',
    '[1, 2, 3, *rest]',
    '{"key": "value", "key2": 456}',
    '{"key": "value with \\"quotes\\""}',  # Testing escaped quotes
    '{"key": "value\\nwith newline"}',
    '{"key": "value\\twith tab"}',
    '{"key": "value\\rwith carriage return"}',
    '{"key": "value\\\\with backslash"}',
    '123.45',
    'True',
    'False',
    'None',
    '[]',
    '{}',
    '{"a": "b", "c": {"d": [1, 2, False]}}'
]

# Invalid JSON examples (incomplete, for demonstration)
invalid_selector_examples = [
    '{"key": value}',  # Missing quotes around value
    '[1, 2,]',  # Trailing comma
    '{"key": }',  # Missing value
    'truefalse' #Should fail
]


for selector_string in selector_examples:
    tree = parser.parse(selector_string)
    if tree:
        print(f"Selector: {selector_string}")
        print(f"Parse Tree: {tree.pretty()}")
        #transformed = parser.transform(tree, SelectorTransformer)
        #print(f"Transformed: {transformed}")
        print("-" * 20)
    else:
        print(f"Selector: {selector_string} - Parse failed.")
        print("-" * 20)

print("Testing Invalid Selector:")
for selector_string in invalid_selector_examples:
    tree = parser.parse(selector_string)
    if tree:
        print(f"Unexpected Success!  Invalid Selector: {selector_string}")
        print(f"Parse Tree: {tree.pretty()}")
    else:
        print(f"Correctly Failed to Parse: {selector_string}")
    print("-" * 20)
# Out:
# Selector: {"key": "value"}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value"
#   None
#
# --------------------
# Selector: {"key": 123}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     number	123
#   None
#
# --------------------
# Selector: {key: "value"}
# Parse Tree: object
#   pair
#     key	key
#     string	"value"
#   None
#
# --------------------
# Selector: {key: $var}
# Parse Tree: object
#   pair
#     key	key
#     variable	$var
#   None
#
# --------------------
# Selector: {"key": True}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     true
#   None
#
# --------------------
# Selector: {"key": False}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     false
#   None
#
# --------------------
# Selector: {"key": None}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     null
#   None
#
# --------------------
# Selector: {"key": [1, 2, 3]}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     array
#       number	1
#       number	2
#       number	3
#       None
#   None
#
# --------------------
# Selector: {"key": {"nested": "value"}}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     object
#       pair
#         key
#           string	"nested"
#         string	"value"
#       None
#   None
#
# --------------------
# Selector: {k:122, **rest}
# Parse Tree: object
#   pair
#     key	k
#     number	122
#   kwargs	**rest
#
# --------------------
# Selector: [1, 2, 3]
# Parse Tree: array
#   number	1
#   number	2
#   number	3
#   None
#
# --------------------
# Selector: [1, 2, 3, *rest]
# Parse Tree: array
#   number	1
#   number	2
#   number	3
#   args	*rest
#
# --------------------
# Selector: {"key": "value", "key2": 456}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value"
#   pair
#     key
#       string	"key2"
#     number	456
#   None
#
# --------------------
# Selector: {"key": "value with \"quotes\""}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value with \"quotes\""
#   None
#
# --------------------
# Selector: {"key": "value\nwith newline"}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value\nwith newline"
#   None
#
# --------------------
# Selector: {"key": "value\twith tab"}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value\twith tab"
#   None
#
# --------------------
# Selector: {"key": "value\rwith carriage return"}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value\rwith carriage return"
#   None
#
# --------------------
# Selector: {"key": "value\\with backslash"}
# Parse Tree: object
#   pair
#     key
#       string	"key"
#     string	"value\\with backslash"
#   None
#
# --------------------
# Selector: 123.45
# Parse Tree: number	123.45
#
# --------------------
# Selector: True
# Parse Tree: true
#
# --------------------
# Selector: False
# Parse Tree: false
#
# --------------------
# Selector: None
# Parse Tree: null
#
# --------------------
# Selector: []
# Parse Tree: array
#   None
#   None
#
# --------------------
# Selector: {}
# Parse Tree: object
#   None
#   None
#
# --------------------
# Selector: {"a": "b", "c": {"d": [1, 2, False]}}
# Parse Tree: object
#   pair
#     key
#       string	"a"
#     string	"b"
#   pair
#     key
#       string	"c"
#     object
#       pair
#         key
#           string	"d"
#         array
#           number	1
#           number	2
#           false
#           None
#       None
#   None
#
# --------------------
# Testing Invalid Selector:
# Error: Unexpected characters in JSON: No terminal matches 'v' in the current parser context, at line 1 col 9
#
# {"key": value}
#         ^
# Expected one of:
# 	* NONE
# 	* SIGNED_NUMBER
# 	* TRUE
# 	* LBRACE
# 	* LSQB
# 	* ESCAPED_STRING
# 	* __ANON_2
# 	* FALSE
#
# Correctly Failed to Parse: {"key": value}
# --------------------
# Unexpected Success!  Invalid Selector: {key: "value"}
# Parse Tree: object
#   pair
#     key	key
#     string	"value"
#   None
#
# --------------------
# Error: Unexpected characters in JSON: No terminal matches ']' in the current parser context, at line 1 col 7
#
# [1, 2,]
#       ^
# Expected one of:
# 	* NONE
# 	* __ANON_0
# 	* SIGNED_NUMBER
# 	* TRUE
# 	* LBRACE
# 	* LSQB
# 	* ESCAPED_STRING
# 	* __ANON_2
# 	* FALSE
#
# Correctly Failed to Parse: [1, 2,]
# --------------------
# Error: Unexpected characters in JSON: No terminal matches '}' in the current parser context, at line 1 col 9
#
# {"key": }
#         ^
# Expected one of:
# 	* NONE
# 	* SIGNED_NUMBER
# 	* TRUE
# 	* LBRACE
# 	* LSQB
# 	* ESCAPED_STRING
# 	* __ANON_2
# 	* FALSE
#
# Correctly Failed to Parse: {"key": }
# --------------------
# Error: Unexpected characters in JSON: No terminal matches 't' in the current parser context, at line 1 col 1
#
# truefalse
# ^
# Expected one of:
# 	* NONE
# 	* SIGNED_NUMBER
# 	* TRUE
# 	* LBRACE
# 	* LSQB
# 	* ESCAPED_STRING
# 	* __ANON_2
# 	* FALSE
#
# Correctly Failed to Parse: truefalse
# --------------------
